# %%
import pandas as pd
import numpy as np
import analyzer as an
import matplotlib.pyplot as plt
import seaborn as sns
import math
pd.options.mode.chained_assignment = None 

df = pd.read_csv("problems.csv", delimiter=";")

# %%
total_problems = an.total_problems(df).sort_values(ascending=False).reset_index(name="Задачи").rename(columns={"index":"Имя"})

plt.figure(figsize=(15, 5))
plt.title("Количество решенных задач", weight="heavy", size=14)
sns.barplot(total_problems, x="Имя", y="Задачи", palette="hls", hue="Имя")
#plt.axhline(total_problems["Задачи"].mean())
plt.show()

# %%
comp_points = an.competative_points(df, weight_func = "sigm").sort_values(ascending=False).reset_index(name="Очки").rename(columns={"index":"Имя"})

plt.figure(figsize=(15, 5))
plt.title("Соревновательные очки", weight="heavy", size=14)
sns.barplot(comp_points, x="Имя", y="Очки", palette="hls", hue="Имя")
plt.axhline(comp_points["Очки"].mean(), c="black")
#plt.axhline(total_problems["Задачи"].mean())
plt.show()

# %%
points_c = an.competative_points(df, topic='Комбинаторика', weight_func="sqrt")
points_t = an.competative_points(df, topic='ТЧ', weight_func="sqrt")

plt.figure(figsize=(15, 5))
plt.suptitle("Соревновательные очки: Комбинаторика vs ТЧ", size=16, weight='heavy')

plt.subplot(1, 2, 1)
plt.title("Комбинаторика")
plt.barh(points_t.index.tolist(), points_c, color='g')
plt.gca().set_xlim([50, 0])


plt.subplot(1, 2, 2)
plt.title("ТЧ")
plt.barh(points_t.index.tolist(), points_t, color='b')
plt.tick_params(axis='y', labelleft=False, labelright=True, left = False, right=True)
plt.gca().set_xlim([0, 50])



plt.show()

# %%
start_comp_points = an.competative_points(df, days=[1,2], weight_func='sqrt').sort_values(ascending=False).reset_index(name="Очки").rename(columns={"index":"Имя"})

plt.figure(figsize=(15, 5))
plt.title("Соревновательные очки в первые два дня сдачи", weight="heavy", size=14)
sns.barplot(start_comp_points, x="Имя", y="Очки", palette='hls', hue="Имя")
plt.axhline(start_comp_points["Очки"].mean(), c="black")
plt.show()

# %%
comp_points = an.competative_points(df, weight_func='sigm', topic="ТЧ").sort_values(ascending=False).reset_index(name="Очки").rename(columns={"index":"Имя"})

plt.figure(figsize=(15, 5))
plt.title("Очки за ТЧ", weight="heavy", size=14)
sns.barplot(comp_points, x="Имя", y="Очки", palette='hls', hue="Имя")
#plt.axhline(comp_points["Очки"].mean())
plt.show()

# %%
df1 = an.bin_conduit(an.topic_loc(df, topic="Комбинаторика"))
colormap = plt.cm.RdBu
ax = sns.heatmap(
    np.round(df1.corr(numeric_only=True), 2),
    linewidths=0.8,
    vmax=1.0,
    vmin = 0,
    square=True,
    cmap=colormap,
    linecolor="black",
    annot=True,
    annot_kws={"fontsize":8},
)

for i in ax.texts:
    if abs(float(i.get_text())) < 0.5:
        i.set_text("")

plt.title("Таблица корреляции решения задач", weight="heavy", size=14)

plt.show()

# %%
stats = an.stats(df)
stats
# Out:
#               Соревновательные очки  Среднее кол-во очков за задачу  \
# Полина А.                 24.207797                        0.138330
# Андрей Б.                  9.087207                        0.063994
# Дмитрий Б.                28.179601                        0.153987
# Максим Д.                 16.875841                        0.108178
# Марк З.                    2.344058                        0.026637
# Ульяна И.                  2.946457                        0.023385
# Мариам М.                  5.489745                        0.039212
# Дэвид О.                  16.286062                        0.095240
# Иван П.                   13.256436                        0.081328
# Екатерина П.              12.086872                        0.074610
# Валерия С.                 4.918145                        0.037259
# Ксения Х.                 60.918458                        0.274407
#
#               Соревновательные очки в комбинаторике  \
# Полина А.                                  4.265742
# Андрей Б.                                  1.383687
# Дмитрий Б.                                 8.363229
# Максим Д.                                 11.511463
# Марк З.                                    0.642710
# Ульяна И.                                  1.020315
# Мариам М.                                  1.822199
# Дэвид О.                                   9.271710
# Иван П.                                    4.860562
# Екатерина П.                               6.368665
# Валерия С.                                 2.739490
# Ксения Х.                                 21.154886
#
#               Среднее кол-во очков за задачу в комбинаторике  \
# Полина А.                                           0.055399
# Андрей Б.                                           0.022318
# Дмитрий Б.                                          0.099562
# Максим Д.                                           0.140384
# Марк З.                                             0.016480
# Ульяна И.                                           0.015229
# Мариам М.                                           0.026409
# Дэвид О.                                            0.109079
# Иван П.                                             0.060007
# Екатерина П.                                        0.077667
# Валерия С.                                          0.035578
# Ксения Х.                                           0.209454
#
#               Соревновательные очки в ТЧ  Среднее кол-во очков за задачу в ТЧ  \
# Полина А.                      18.928171                             0.236602
# Андрей Б.                       7.682801                             0.120044
# Дмитрий Б.                     19.792443                             0.241371
# Максим Д.                       4.350495                             0.077687
# Марк З.                         1.677418                             0.052419
# Ульяна И.                       1.902212                             0.045291
# Мариам М.                       3.650037                             0.065179
# Дэвид О.                        6.990423                             0.101310
# Иван П.                         8.371945                             0.128799
# Екатерина П.                    5.694277                             0.090385
# Валерия С.                      2.154725                             0.056703
# Ксения Х.                      36.762945                             0.363990
#
#               Соревновательные очки в графах  \
# Полина А.                           1.013884
# Андрей Б.                           0.020719
# Дмитрий Б.                          0.023930
# Максим Д.                           1.013884
# Марк З.                             0.023930
# Ульяна И.                           0.023930
# Мариам М.                           0.017509
# Дэвид О.                            0.023930
# Иван П.                             0.023930
# Екатерина П.                        0.023930
# Валерия С.                          0.023930
# Ксения Х.                           3.000627
#
#               Среднее кол-во очков за задачу в графах  \
# Полина А.                                    0.056327
# Андрей Б.                                    0.001295
# Дмитрий Б.                                   0.001408
# Максим Д.                                    0.056327
# Марк З.                                      0.001408
# Ульяна И.                                    0.001408
# Мариам М.                                    0.001167
# Дэвид О.                                     0.001408
# Иван П.                                      0.001408
# Екатерина П.                                 0.001408
# Валерия С.                                   0.001408
# Ксения Х.                                    0.150031
#
#               Стартовые соревновательные очки
# Полина А.                           30.548151
# Андрей Б.                           26.495739
# Дмитрий Б.                          36.379137
# Максим Д.                            8.283692
# Марк З.                              9.301931
# Ульяна И.                            1.005035
# Мариам М.                            6.624523
# Дэвид О.                            34.801339
# Иван П.                             46.775947
# Екатерина П.                        14.888027
# Валерия С.                           3.954840
# Ксения Х.                          100.117343

# %%
an.personal_stats(stats, "Валерия С.")
# Out:
# Валерия С.
# Соревновательные очки: 4.92, #10
# Среднее кол-во очков за задачу: 0.04, #10
# Соревновательные очки в комбинаторике: 2.74, #8
# Среднее кол-во очков за задачу в комбинаторике: 0.04, #8
# Соревновательные очки в ТЧ: 2.15, #10
# Среднее кол-во очков за задачу в ТЧ: 0.06, #10
# Соревновательные очки в графах: 0.02, #4
# Среднее кол-во очков за задачу в графах: 0.0, #4
# Стартовые соревновательные очки: 3.95, #11
